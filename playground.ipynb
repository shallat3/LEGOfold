# %%
from LegoProtein import LegoProtein
import networkx as nx


iga = LegoProtein(10,uniprot="P01876")
# Out:
#           x         y         z amino_acid
# 0  5.793279  3.167760  5.235306        ALA
# 1  5.966127  3.258134  5.209533        ALA
# 2  6.078993  3.257464  5.352122        ALA
# 3  5.932655  3.448387  5.152296        ALA
# 4  6.004017  3.246352  5.473736        ALA
# (10, 10, 10)
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# need a connection
# ...

# %%
graph = iga.connection_graph()

print(graph.edges())

print(nx.number_connected_components(graph))
# Out:
# [('(8, 1)at(0, 6, 5)', '(2, 3)at(2, 5, 6)'), ('(8, 1)at(0, 6, 5)', '(1, 6)at(1, 2, 6)'), ('(8, 1)at(0, 6, 5)', '(1, 1)at(6, 6, 4)'), ('(8, 1)at(0, 6, 5)', '(2, 6)at(5, 4, 6)'), ('(8, 1)at(0, 6, 5)', '(1, 1)at(4, 6, 4)'), ('(8, 1)at(0, 6, 5)', '(1, 6)at(7, 4, 6)'), ('(8, 1)at(0, 6, 5)', '(1, 3)at(3, 6, 4)'), ('(8, 1)at(0, 6, 5)', '(2, 4)at(1, 5, 4)'), ('(8, 1)at(0, 7, 5)', '(2, 3)at(2, 5, 6)'), ('(8, 1)at(0, 7, 5)', '(1, 6)at(1, 2, 6)'), ('(8, 1)at(0, 7, 5)', '(2, 6)at(5, 4, 6)'), ('(8, 1)at(0, 7, 5)', '(2, 2)at(6, 7, 4)'), ('(8, 1)at(0, 7, 5)', '(1, 6)at(7, 4, 6)'), ('(8, 1)at(0, 7, 5)', '(1, 3)at(3, 6, 4)'), ('(8, 1)at(0, 7, 5)', '(2, 4)at(1, 5, 4)'), ('(2, 6)at(5, 4, 6)', '(4, 2)at(5, 8, 5)'), ('(2, 6)at(5, 4, 6)', '(1, 1)at(6, 8, 7)'), ('(2, 6)at(5, 4, 6)', '(1, 1)at(6, 4, 7)'), ('(2, 6)at(5, 4, 6)', '(2, 2)at(6, 5, 7)'), ('(2, 6)at(5, 4, 6)', '(1, 1)at(5, 9, 7)'), ('(2, 6)at(5, 4, 6)', '(3, 2)at(5, 4, 5)'), ('(6, 2)at(2, 5, 1)', '(1, 1)at(4, 5, 0)'), ('(6, 2)at(2, 5, 1)', '(4, 1)
# ...
